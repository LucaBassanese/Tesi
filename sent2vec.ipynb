# %% [markdown]
# # Set up environemnt

# %%
# setup sent2vec
! git clone https://github.com/epfml/sent2vec.git
# %cd sent2vec
! make
# Out:
# Cloning into 'sent2vec'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 379 (delta 3), reused 6 (delta 1), pack-reused 368
# Receiving objects: 100% (379/379), 446.78 KiB | 2.52 MiB/s, done.
# Resolving deltas: 100% (231/231), done.
# /content/sent2vec
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/args.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/dictionary.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/productquantizer.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/matrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/shmem_matrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/qmatrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/vector.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/model.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/utils.cc
# ...

# %%
pip install .
# Out:
# Processing /content/sent2vec
# ...
#   Created wheel for sent2vec: filename=sent2vec-0.0.0-cp36-cp36m-linux_x86_64.whl size=1125797 sha256=1059e749c6e94c21b1a87188e6519d702ac7816664eac57509f5c5894475ba1d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2bmpk4it/wheels/b1/65/d7/f2c679e0086741bea69f0c4478303b6506bbf4c78dea82f565
# Successfully built sent2vec
# ...

# %%
import pandas as pd
import sent2vec

frasi = pd.read_csv('frasi.txt', header = None, names= ['parole'])
parole = pd.read_csv('keyword.txt', header = None, names= ['parole'])

# %% [markdown]
# # Sent2vec model

# %% [markdown]
# ## Frasi ns

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 21121  lr: 0.000000  loss: 3.513137  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 20798  lr: 0.000000  loss: 3.747321  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 20145  lr: 0.000000  loss: 3.912092  eta: 0h0m

# %% [markdown]
# ## Frasi hs

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss hs -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 143141  lr: 0.000000  loss: 7.719068  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss hs -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 116423  lr: 0.000000  loss: 7.660804  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss hs -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 94802  lr: 0.000000  loss: 7.788303  eta: 0h0m

# %% [markdown]
# ## Frasi softmax

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss softmax -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 831  lr: 0.000000  loss: 17.595551  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss softmax -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 644  lr: 0.000000  loss: 17.594296  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss softmax -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 525  lr: 0.000000  loss: 17.592552  eta: 0h0m

# %% [markdown]
# ## Bigram ns

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 300 -epoch 20
# Out:
# Read 0M words
# Number of words:  9625
# Number of labels: 0
# tcmalloc: large alloc 2411552768 bytes == 0x55a88b3cc000 @  0x7fca6789d887 0x55a88228feec 0x55a8822ac378 0x55a8822a9c0b 0x55a8822ae075 0x55a882276692 0x7fca66732b97 0x55a88227699a
# Progress: 100.0%  words/sec/thread: 11493  lr: 0.000000  loss: 4.071548  eta: 0h0m

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 400 -epoch 20

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 500 -epoch 20

# %% [markdown]
# ## Bigrams hs

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss hs

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss hs

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss hs

# %% [markdown]
# ## Bigrams softmax

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss softmax

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss softmax

# %%
! ./fasttext sent2vec -input frasi_bi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss softmax

# %% [markdown]
# ## Trigrams ns

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 2403901440 bytes == 0x555ff6b0c000 @  0x7f567546e887 0x555fedda6eec 0x555feddc3378 0x555feddc0c0b 0x555feddc5075 0x555fedd8d692 0x7f5674303b97 0x555fedd8d99a
# Progress: 100.0%  words/sec/thread: 20089  lr: 0.000000  loss: 4.343495  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 3205201920 bytes == 0x556753b78000 @  0x7ff4d0d37887 0x55674b52feec 0x55674b54c378 0x55674b549c0b 0x55674b54e075 0x55674b516692 0x7ff4cfbccb97 0x55674b51699a
# Progress: 100.0%  words/sec/thread: 19376  lr: 0.000000  loss: 3.559962  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 4006502400 bytes == 0x56424c380000 @  0x7fc949085887 0x56424283aeec 0x564242857378 0x564242854c0b 0x564242859075 0x564242821692 0x7fc947f1ab97 0x56424282199a
# Progress: 100.0%  words/sec/thread: 18678  lr: 0.000000  loss: 4.080315  eta: 0h0m

# %% [markdown]
# ## Trigrams hs

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss hs -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 2403901440 bytes == 0x55b22df5e000 @  0x7f72e0ec1887 0x55b224a51eec 0x55b224a6e378 0x55b224a6bc0b 0x55b224a70075 0x55b224a38692 0x7f72dfd56b97 0x55b224a3899a
# Progress: 100.0%  words/sec/thread: 104191  lr: 0.000000  loss: 7.795591  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss hs -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 3205201920 bytes == 0x55b2cf07e000 @  0x7f8c530c1887 0x55b2c5b2eeec 0x55b2c5b4b378 0x55b2c5b48c0b 0x55b2c5b4d075 0x55b2c5b15692 0x7f8c51f56b97 0x55b2c5b1599a
# Progress: 100.0%  words/sec/thread: 82971  lr: 0.000000  loss: 7.826329  eta: 0h0m

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss hs -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 4006502400 bytes == 0x55c466b90000 @  0x7f9bfb49f887 0x55c45ecf2eec 0x55c45ed0f378 0x55c45ed0cc0b 0x55c45ed11075 0x55c45ecd9692 0x7f9bfa334b97 0x55c45ecd999a
# Progress: 100.0%  words/sec/thread: 68763  lr: 0.000000  loss: 7.809840  eta: 0h0m

# %% [markdown]
# ## Trigrams softmax

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss softmax -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 2403901440 bytes == 0x565475fbe000 @  0x7fee56764887 0x56546c46eeec 0x56546c48b378 0x56546c488c0b 0x56546c48d075 0x56546c455692 0x7fee555f9b97 0x56546c45599a
# Progress: 100.0%  words/sec/thread: 828  lr: 0.000000  loss: 17.749035  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss softmax -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 3205201920 bytes == 0x55ee2f8bc000 @  0x7f5c9412d887 0x55ee277bfeec 0x55ee277dc378 0x55ee277d9c0b 0x55ee277de075 0x55ee277a6692 0x7f5c92fc2b97 0x55ee277a699a
# Progress: 100.0%  words/sec/thread: 643  lr: 0.000000  loss: 17.749035  eta: 0h0m

# %%
#! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss softmax -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 4006502400 bytes == 0x5575463a8000 @  0x7f5c6db0c887 0x55753c95feec 0x55753c97c378 0x55753c979c0b 0x55753c97e075 0x55753c946692 0x7f5c6c9a1b97 0x55753c94699a
# Progress: 100.0%  words/sec/thread: 523  lr: 0.000000  loss: 17.749029  eta: 0h0m

# %% [markdown]
# ## Applicazione

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
a = model.embed_sentences(frasi.parole)
b = pd.DataFrame(a)
b.to_csv('/content/sent2vec_tri_softmax_500.csv', index= False)

# %% [markdown]
# # Applicazione Keyword

# %% [markdown]
# ## Uni

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss hs -wordNgrams 1

# %%
#cosine similarity
from scipy import spatial
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin')

# %%
#combinazioni
from itertools import combinations 
comb = combinations(list(parole.parole), 2)

# %%
sims = []
ind_comb = []
for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)
  ind_comb.append(str(i[0]) + ' - ' + str(i[1]))
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
matriciona = pd.DataFrame(columns= ind_comb)
matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod = ['sent2vec_uni_hs_300']

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss hs -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 140701  lr: 0.000000  loss: 7.759313  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_uni_hs_400')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss hs -wordNgrams 1
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# Progress: 100.0%  words/sec/thread: 116439  lr: 0.000000  loss: 7.724864  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_uni_hs_500')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %% [markdown]
# ## Bigrams

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss hs -wordNgrams 2
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 2403901440 bytes == 0x55f085cc0000 @  0x7ff0b4116887 0x55f07d7d6eec 0x55f07d7f3378 0x55f07d7f0c0b 0x55f07d7f5075 0x55f07d7bd692 0x7ff0b2fabb97 0x55f07d7bd99a
# Progress: 100.0%  words/sec/thread: 138327  lr: 0.000000  loss: 7.791500  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_bi_hs_300')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss hs -wordNgrams 2
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 3205201920 bytes == 0x562821e22000 @  0x7febc3062887 0x562819194eec 0x5628191b1378 0x5628191aec0b 0x5628191b3075 0x56281917b692 0x7febc1ef7b97 0x56281917b99a
# Progress: 100.0%  words/sec/thread: 112035  lr: 0.000000  loss: 7.761381  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_bi_hs_400')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss hs -wordNgrams 2
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 4006502400 bytes == 0x563484ada000 @  0x7f90167a2887 0x56347c94aeec 0x56347c967378 0x56347c964c0b 0x56347c969075 0x56347c931692 0x7f9015637b97 0x56347c93199a
# Progress: 100.0%  words/sec/thread: 92061  lr: 0.000000  loss: 7.802079  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_bi_hs_500')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %% [markdown]
# ## Trigrams

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 300 -epoch 20 -loss hs -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 2403901440 bytes == 0x55b610b0a000 @  0x7f70fd4fe887 0x55b6070c5eec 0x55b6070e2378 0x55b6070dfc0b 0x55b6070e4075 0x55b6070ac692 0x7f70fc393b97 0x55b6070ac99a
# Progress: 100.0%  words/sec/thread: 118351  lr: 0.000000  loss: 7.802365  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_tri_hs_300')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 400 -epoch 20 -loss hs -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 3205201920 bytes == 0x55f32239a000 @  0x7f9626cf5887 0x55f3186e8eec 0x55f318705378 0x55f318702c0b 0x55f318707075 0x55f3186cf692 0x7f9625b8ab97 0x55f3186cf99a
# Progress: 100.0%  words/sec/thread: 93653  lr: 0.000000  loss: 7.789183  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_tri_hs_400')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
! ./fasttext sent2vec -input frasi.txt -output my_model -minCount 0 -dim 500 -epoch 20 -loss hs -wordNgrams 3
# Out:
# Read 0M words
# Number of words:  3249
# Number of labels: 0
# tcmalloc: large alloc 4006502400 bytes == 0x558f1f43c000 @  0x7f07a174f887 0x558f16dd5eec 0x558f16df2378 0x558f16defc0b 0x558f16df4075 0x558f16dbc692 0x7f07a05e4b97 0x558f16dbc99a
# Progress: 100.0%  words/sec/thread: 77259  lr: 0.000000  loss: 7.773007  eta: 0h0m

# %%
model = sent2vec.Sent2vecModel()
model.load_model('my_model.bin') 
comb = combinations(list(parole.parole), 2)
sims = []

for i in list(comb):
  v1 = model.embed_sentence(i[0])
  v2 = model.embed_sentence(i[1])
  sim = round(1-spatial.distance.cosine(v1, v2), 3)
  # print(f'First: {i[0]}, Second: {i[1]},\
  # Similarity: {sim}')
  sims.append(sim)


matriciona = matriciona.append(pd.Series(sims, index=matriciona.columns ), ignore_index= True)
ind_mod.append('sent2vec_tri_hs_500')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
matriciona.index = ind_mod
matriciona.to_excel('matricionasent.xlsx')

# %%
matriciona
